# %% [markdown]
# <a href="https://colab.research.google.com/github/LRAzizova/MyHomeWork/blob/main/1_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
x=float(input('x='))
z=(x**2-7*x+10)/(x**2-8*x+12)
print(z)
# Out:
# x=1
# 0.8

# %% [markdown]
# 2.

# %%
import math
x=float(input('x'))
y=((1-math.cos(2*x)+math.sin(2*x)))/((1+math.cos(2*x)+math.sin(2*x)))
print(y)
# Out:
# x2
# -2.185039863261519

# %% [markdown]
# 3.

# %%
import math
x1=float(input('x1'))
x2=float(input('x2'))
x3=float(input('x3'))
y1=float(input('y1'))
y2=float(input('y2'))
y3=float(input('y3'))
p1=math.sqrt((x2-x1)*2+(y2-y1)*2)
p2=math.sqrt((x3-x2)*2+(y3-y2)*2)
p3=math.sqrt((x3-x1)*2+(y3-y1)*2)
p=p1+p2+p3
s=0,5*((x1-x3)*(y2-y3)-(x2-x3)*(y2-y3))
print(p,s)
# Out:
# x1-3
# x25
# x35
# y13
# y2-1
# y35
# 10.764664694883525 (0, 240.0)

# %% [markdown]
# 4.

# %%
a = int(input('a='))
b = int(input('b='))
num_segments = a//b
print(num_segments)
# Out:
# a=9
# b=6
# 1

# %% [markdown]
# 5.

# %%
x1 = int(input('x1='))
y1 = int(input('y1='))
x2 = int(input('x2='))
y2 = int(input('y2='))
dx = abs(x1 - x2)
dy = abs(y1 - y2)
(dx == 2 and dy == 1) or (dx == 1 and dy == 2)2
# Out:
# x1=1
# y1=3
# x2=2
# y2=3
# False
