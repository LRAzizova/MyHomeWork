# %% [markdown]
# <a href="https://colab.research.google.com/github/LRAzizova/MyHomeWork/blob/main/2_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
import math
x=float(input('x='))
if x<=3:
  f=(x**2)-3*x+9
else:
  f=1/(x**3+1)
print (f)
# Out:
# x=3
# 9.0

# %% [markdown]
# 2

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
if a>=0:
  a=a**2
if b>=0:
  b=b**2
if c>=0:
  c=c**2
if a<0:
  a=a**4
if b<0:
  b=b**4
if c<0:
  c=c**4
print (a,b,c)
# Out:
# a=2
# b=3
# c=-1
# 4.0 9.0 1.0

# %% [markdown]
# 3

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
d=float(input('d='))
mx=a
mn=c
if mx<b:
  mx=b

if mn>d:
  mn=d
print (mx,mn)
# Out:
# a=9
# b=8
# c=7
# d=6
# 9.0 6.0

# %% [markdown]
# 4a

# %%
a=float(input('a='))
b=float(input('b='))
mx=a
if mx<b:
  mx=b
print (mx)
# Out:
# a=3
# b=8
# 8.0

# %% [markdown]
# 4б

# %%
a=float(input('a='))
b=float(input('b='))
mn=a
if mn>b:
  mx=b
print (mn)
# Out:
# a=3
# b=8
# 3.0

# %% [markdown]
# 5

# %%
x = int(input())
if (x < 1) + (x > 7):
    print("Введите цифру от 1 до 7")
elif x == 1:
    print("Понедельник")
elif x == 2:
    print("Вторник")
elif x == 3:
    print("Среда")
elif x == 4:
    print("Четверг")
elif x == 5:
    print("Пятница")
elif x == 6:
    print("Суббота")
else:
    print("Воскресенье")
# Out:
# 4
# Четверг
